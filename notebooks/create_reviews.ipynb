# %%
<experiment_description>
{experiment_description}
</experiment_description>

<biological_context>
{biological_context}
</biological_context>

<dataset>
{data}
</dataset>

<hypotheses>
{hypotheses_text}
</hypotheses>

<instructions>
<task>

The experiment described above generated the dataset. The experiment description includes the rationale behind the experiment and the overall purpose of the research. Scientists on the research project reviewed the dataset and developed the provided hypotheses to explain selected observed data and provide mechanistic insight into the biological processes underlying the data. 

Your task is to review and rank the hypotheses according to the following criteria. Each hypothesis should:

Accurately use the data: Double-check that all data mentioned in the hypothesis match the dataset. Minor differences in measurement values detract from the hypothesis, and major differences or hallucinated values invalidate it.

Accurately use scientific knowledge in support of the hypothesis: Assertions about the types, behaviors, properties, or interactions of genes, proteins, phenotypes, or diseases must be accurate and not hallucinated. Minor errors that do not affect the logic of the hypothesis detract from it, errors critical to the logic invalidate it.

Use correct reasoning: The logic of the hypothesis must be correct.

Be based on causal mechanisms that explain elements of the data: The hypothesis should present chains of causation, potentially including feedback paths, that explain observations in the dataset.

Be plausible: The roles of entities and their causal relationships presented in the hypothesis should largely be known or consistent with current science. Proposed new roles or relationships (or those new to the experimental context) should be well supported.

Be novel: Cases in which well-known mechanisms explain data elements are not interesting except as they form supporting structures for novel mechanisms.

Be relevant to the higher-level goals of the experiment. For example, if the goal is drug target discovery, a novel causal mechanism leading to a disease phenotype is interesting. 

Be actionable: It should be possible to test the hypothesis with relatively low-cost experimental techniques.

</task>

<review_process>
1. review each hypothesis, outputting brief notes on its merits relative to the above criteria. If the hypothesis fails any of the criteria for accuracy and correctness of reasoning, mark it as unacceptable and move on to the next hypothesis.

<example>
Initial Review:
Hypothesis#1
...brief notes
Hypothesis#2
...brief notes
(and so on)
</example>

2. Assign each hypothesis a rank, where the minimum rank is 1, and the maximum is the number of hypotheses. For any pair of hypotheses where you do not strongly prefer one over another, you should give them the same rank. Any unacceptable hypotheses get the lowest rank of 1.

The format must be exactly as shown in the example, where each hypothesis line has the form "Hypothesis#<order of the hypothesis>: <rank>"

<example>
Initial Rankings:
Hypothesis#1: 3
Hypothesis#2: 2
...and so on
</example>
 
3. Perform a second review, challenging your first review. Be especially aware of any cognitive biases that you may have been prey to, such as being sensitive to the order of the hypotheses or to writing styles.

<example>
Second Review:
Hypothesis#1
...brief notes
Hypothesis#2
...brief notes
(and so on)
</example>

4. Output the rankings, revising as per your second review.

<example>
Final Rankings:
Hypothesis#1: 3
Hypothesis#2: 2
...and so on
</example>

5. output a summary review that explains your rankings.

Here is an example of a review.
<example>

Summary Review:
After a careful review of the three hypotheses presented, I ranked Hypothesis #1 as the best one, rank=1, while hypotheses #2 and #3 are tied, rank=3.

Hypothesis #1 is best because:
It provides a clear and detailed mechanism involving both transcriptional and post-translational modifications. It explains how ZNF618 could be involved in the transcriptional regulation of genes important for the innate immune response and cell cycle regulation, while UBE2L6 could be involved in the ubiquitination and degradation of proteins during Dengue virus infection. The roles of the proteins involved support this dual mechanism of action.

It is grounded in known molecular functions of the proteins involved. ZNF618's role in transcriptional regulation and UBE2L6's function in protein ubiquitination are well-documented, making their proposed roles in response to Dengue virus infection plausible.

It proposes a specific interaction between transcriptional changes mediated by ZNF618 and ubiquitin-mediated protein degradation by UBE2L6 in the context of Dengue virus infection. This interaction has not been extensively studied, providing a novel insight into the cellular response to viral infection.

It is actionable as it can be validated using relatively simple and cost-effective experimental techniques such as chromatin immunoprecipitation (ChIP) followed by sequencing to identify the genomic binding sites of ZNF618, and proteasome inhibition experiments in the presence of UBE2L6 knockdown to determine the specific targets of UBE2L6-mediated ubiquitination. These experiments are feasible and would provide significant insights into the molecular mechanisms proposed.

In comparison, while Hypotheses #2 and #3 also present interesting and plausible mechanisms, they either lack the detailed interaction between molecular components seen in Hypothesis #1 (Hypothesis #2) or propose mechanisms that, while novel, might require more complex and less straightforward experimental approaches to validate (Hypothesis #3). Hypothesis #1 not only integrates multiple molecular pathways but also suggests straightforward experimental approaches for validation, making it the strongest candidate based on the criteria provided.
</example>

<review process>
</instructions>

# %%
<experiment_description>
{experiment_description}
</experiment_description>

<biological_context>
{biological_context}
</biological_context>

<dataset>
{data}
</dataset>

<hypotheses>
{hypotheses_text}
</hypotheses>

<instructions>
<task>
Review and rank hypotheses explaining experimental data based on these criteria:
1. Accurate use of data
2. Accurate use of scientific knowledge
3. Correct reasoning
4. Based on causal mechanisms explaining data
5. Plausible
6. Novel
7. Relevant to experiment goals
8. Actionable

Hypotheses failing accuracy or reasoning criteria are unacceptable.
</task>

<review_process>
1. Review each hypothesis, noting merits relative to criteria. Mark unacceptable ones.

<example>
Initial Review:
Hypothesis#1
...brief notes
Hypothesis#2
...brief notes
(and so on)
</example>

2. Rank hypotheses (minimum 1, maximum = number of hypotheses). Use same rank for equal preference. Unacceptable hypotheses get rank 1. You must output your rankings in EXACTLY format in the following example:

<example>
Initial Rankings:
Hypothesis#1: 3
Hypothesis#2: 2
...and so on
</example>

3. Perform a second review, challenging your first review. Be aware of cognitive biases.

<example>
Second Review:
Hypothesis#1
...brief notes
Hypothesis#2
...brief notes
(and so on)
</example>

4. Output revised rankings. You must output your rankings in EXACTLY format in the following example:

<example>
Final Rankings:
Hypothesis#1: 3
Hypothesis#2: 2
...and so on
</example>

5. Provide a summary review explaining your rankings. You must output the Summary Review exactly as in the following example.

<example>
Summary Review:
After careful review, I ranked Hypothesis #1 as best (rank=1), while hypotheses #2 and #3 are tied (rank=3).

Hypothesis #1 is best because:
[Brief explanation of strengths]

In comparison, Hypotheses #2 and #3 [Brief comparison]
</example>

</review_process>
</instructions>
